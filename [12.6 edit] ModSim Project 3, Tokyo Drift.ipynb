# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

import pandas as pd
import numpy as np

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

# %%
def dFunc(t):
    d = 1
    return d

# %%
def wFunc(t):
    #w = 10*(1 - np.e**(-10*t))
    w = 10
    return w

# %%
deg = np.pi/180

system = System(init = State(Vx = 0, Vy = 0, X = 0, Y = 0, B = 0, Wb=0),
                w = wFunc,
                d = 30 * deg,
                r = 0.3,
                I = 2500,
                l = 2.52,
                h = 0.28,
                m = 1250,
                Fxk = Params(B = 0.12, C = 1.48, D = 3308, E = 0.01, K = 100),
                Fya = Params(B = 0.08, C = 1.44, D = 6004, E = -1.84, K = 90),
                t_end = 10 
                )
# Out:
# init     Vx    0
# Vy    0
# X     0
# Y     0
# B     0
# Wb    ...
# w                   <function wFunc at 0x0000020B27B81950>
# d                                                 0.523599
# r                                                      0.3
# I                                                     2500
# l                                                     2.52
# h                                                     0.28
# m                                                     1250
# Fxk      B       0.12
# C       1.48
# D    3308.00
# E      ...
# Fya      B       0.08
# C       1.44
# D    6004.00
# E      ...
# t_end                                                   10
# dtype: object

# %%
def AlphaF(sys, state):
    unpack(sys)
    Vx, Vy, X, Y, B, Wb = state
    
    Vxf = (Wb * (l / 2)) + np.cos(B) * Vx
    Vyf = Vy * np.sin(B) - Wb * (l/2)
    
    if(Vxf == 0):
        Vxf = 1e-99
    
    af = np.arctan(Vyf / Vxf) - d
    
    #print("AlphaF")
    #print(af)
    
    return af
    
    
def AlphaR(sys, state):
    unpack(sys)
    Vx, Vy, X, Y, B, Wb = state
    
    Vxr = (Wb * (l / 2)) + np.cos(B) * Vx
    Vyr = Vy * np.sin(B) - Wb * (l/2)
    
    if(Vxr == 0):
        Vxr = 1e-99
        
    ar = np.arctan(Vyr / Vxr)
    
    #print("AlphaR")
    #print(ar)
    
    return ar

# %%
def slip(sys, state, t):
    unpack(sys)
    Vx, Vy, X, Y, B, Wb = state
    
    Vxr = (Wb * (l / 2)) + np.cos(B) * Vx
    
    if(t==0):
        K = 1
    else:
        K = (r * w(t) - Vxr) / (r * w(t))
    
    #print("slip")
    #print(K)
    
    return K

# %%
def BNPFrictionX(sys, state, k):
    unpack(sys)
    #unpack(Fxk)
    
    phi = (1-Fxk.E)*Fxk.K*k + (Fxk.E/Fxk.B)*np.arctan(Fxk.B*Fxk.K*k)
    Fx  = Fxk.D*np.sin(Fxk.C*np.arctan(Fxk.B*phi))
    
    #print("BNPFrictionX")
    #print(Fx)
    
    return Fx

# %%
def BNPFrictionY(sys, state, a):
    unpack(sys)
    #unpack(Fya)
    
    #print(a)
    
    phi = (1-Fya.E)*Fya.K*a + (Fya.E/Fya.B)*np.arctan(Fya.B*Fya.K*a)
    Fy  = Fya.D*np.sin(Fya.C*np.arctan(Fya.B*phi))
    
    #print("BNPFrictionY")
    #print(Fy)
    
    return Fy

# %%
def NCForceX(sys, state, a, k):
    unpack(sys)    
    
    Fx = BNPFrictionX(sys, state, k)
    Fy = BNPFrictionY(sys, state, a)
    
    num   = Fx*Fy*k
    denom = (k**2 * Fy**2 + Fx**2 * np.tan(a)**2)**.5
    
    if(denom == 0):
        print('Yikes, NCForceX')
    
    F = num/denom
    
    #print("NCForceX")
    #print(F)
    
    return F

# %%
def NCForceY(sys, state, a, k):
    unpack(sys)    
    
    Fx = BNPFrictionX(sys, state, k)
    Fy = BNPFrictionY(sys, state, a)
    
    num   = Fx*Fy*np.tan(a)
    denom = (k**2 * Fy**2 + Fx**2 * np.tan(a)**2)**.5
    
    if(denom == 0):
        print('Yikes, NCForceY')
    
    F = num/denom
    
    #print("NCForceY")
    #print(F)
    
    return F

# %%
def slopeFunc(state, t, sys):
    unpack(sys)
    Vx, Vy, X, Y, B, Wb = state
    
    if(t==0):
        af = d
    else:
        af = AlphaF(sys, state)
        if(af == 0):
            print('af')
            print(t)
            af = 1e-99
    
    if(t==0):
        ar = 1e-99
    else:
        ar = AlphaR(sys, state)
        if(ar == 0):
            print('ar')
            print(t)
            ar = 1e-99
    
    kf = 1e-99
    kr = slip(sys, state, t)
    if(kr == 0):
        print(t)
        kr = 1e-99
    
    Fxwf = 1e-99
    Fywf = NCForceY(sys, state, af, kf)
    
    Fxwr = NCForceX(sys, state, ar, kr)
    Fywr = NCForceY(sys, state, ar, kr)
    
    Fx = Fxwr + Fxwf * np.cos(d) - Fywf * np.sin(d)
    Fy = Fywr + Fxwf * np.sin(d) + Fywf * np.cos(d)
    
    T = (l / 2) * (Fywr - Fxwf * np.sin(d) - Fywf * np.cos(d))
    
    dBdt = Wb
    dWbdt = T / I
    dXdt = Vx
    dYdt = Vy
    dVxdt = Fx / m
    dVydt = Fy / m
    
    return dVxdt, dVydt, dXdt, dYdt, dBdt, dWbdt

# %%
slopeFunc(system.init, 0, system)
# Out:
# (0.07473894086337532, 3.571295405143859, 0, 0, 0, -2.249916105240631)

# %%
results, details = run_ode_solver(system, slopeFunc, max_step = 1)

# %%
results
# Out:
#                   Vx         Vy             X             Y             B  \
# 0.000000    0.000000   0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 0.000100   -0.000365   0.000446 -1.651702e-08  2.107170e-08 -8.438556e-09
# 0.000200   -0.000775   0.000862 -7.350127e-08  8.644602e-08 -3.195838e-08
# 0.001079   -0.004373   0.004520 -2.336293e-06  2.451777e-06 -9.740557e-07
# 0.005327   -0.021760   0.022183 -5.784197e-05  5.917507e-05 -2.413864e-05
# 0.047804   -0.195353   0.197419 -4.670732e-03  4.732120e-03 -1.965868e-03
# 0.210228   -0.855616   0.847231 -9.008639e-02  8.996823e-02 -3.900030e-02
# 0.751202   -3.040887   2.862451 -1.144097e+00  1.101133e+00 -5.315806e-01
# 1.066300   -3.747021   4.014488 -2.266803e+00  2.182174e+00 -1.105647e+00
# 1.393563   -3.509633   4.888634 -3.479023e+00  3.675984e+00 -1.909428e+00
# 1.521131   -3.437234   5.326600 -3.922487e+00  4.327991e+00 -2.243230e+00
# 1.603732   -3.366353   5.550616 -4.201976e+00  4.775040e+00 -2.465440e+00
# 1.656125   -3.557397   5.772153 -4.382896e+00  5.071309e+00 -2.612199e+00
# 1.711338   -3.528677   5.801879 -4.579481e+00  5.391238e+00 -2.764135e+00
# 1.794364   -3.634910   6.352898 -4.875963e+00  5.893671e+00 -2.979101e+00
# 1.907478   -3.804087   7.166414 -5.296580e+00  6.658240e+00 -3.269242e+00
# 2.106059   -4.143963   8.603072 -6.084717e+00  8.223894e+00 -3.771182e+00
# 2.334733   -3.804470   8.867768 -7.001531e+00  1.023746e+01 -4.245576e+00
# 9.975683  -17.637876  59.861314 -8.471785e+01  2.682571e+02 -4.540206e+00
# 9.986942  -17.660003  59.943004 -8.491656e+01  2.689315e+02 -4.540424e+00
# 9.987833  -17.661753  59.949466 -8.493228e+01  2.689849e+02 -4.540440e+00
# 9.989528  -17.665084  59.955898 -8.496222e+01  2.690865e+02 -4.540474e+00
# 9.991222  -17.668415  59.968196 -8.499216e+01  2.691881e+02 -4.540508e+00
# 10.000000 -17.685666  60.031884 -8.514732e+01  2.697147e+02 -4.540676e+00
#
#                  Wb
# 0.000000   0.000000
# 0.000100  -0.000150
# 0.000200  -0.000321
# 0.001079  -0.001823
# 0.005327  -0.009087
# 0.047804  -0.082597
# 0.210228  -0.376628
# 0.751202  -1.471572
# 1.066300  -2.174949
# 1.393563  -2.549173
# 1.521131  -2.676371
# 1.603732  -2.752315
# 1.656125  -2.839040
# 1.711338  -2.632091
# 1.794364  -2.576883
# 1.907478  -2.552668
# 2.106059  -2.500950
# 2.334733  -1.560376
# 2.491970  -0.852998
# 2.523393  -0.711615
# 2.533382  -0.666678
# 2.575801  -0.557504
# 2.605942  -0.548936
# 2.652237  -0.447894
# 2.698532  -0.434739
# 2.720721  -0.428429
# 2.755400  -0.352784
# 2.790157  -0.342906
# 2.828972  -0.331869
# 2.842749  -0.327950
# ...             ...
# 9.883999  -0.020387
# 9.890741  -0.018489
# 9.893249  -0.023250
# 9.895757  -0.022544
# 9.909442  -0.018689
# 9.910859  -0.018290
# 9.911689  -0.018056
# 9.912497  -0.019589
# 9.913403  -0.019333
# 9.915852  -0.018644
# 9.917090  -0.018295
# 9.919872  -0.023575
# 9.922653  -0.022792
# 9.937714  -0.018550
# 9.940299  -0.017821
# 9.942458  -0.021920
# 9.944617  -0.021311
# 9.956492  -0.017966
# 9.957491  -0.017685
# 9.959324  -0.021164
# 9.961156  -0.020648
# 9.970436  -0.018034
# 9.971606  -0.017704
# 9.973645  -0.021575
# 9.975683  -0.021000
# 9.986942  -0.017829
# 9.987833  -0.017578
# 9.989528  -0.020796
# 9.991222  -0.020318
# 10.000000 -0.017845
#
# [1183 rows x 6 columns]

# %%
def plotPath(results, label):
    plot(results.X, results.Y, label = label)
    
    decorate(xlabel = 'x position (m)',
             ylabel = 'y position (m)')

# %%
plotPath(results, '10 rad/s')

# %%
plot(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-aa462cf0dd87> in <module>()
# ----> 1 plot(results)
#
# ~\Documents\ModSimPy-Projects\modsim.py in plot(*args, **options)
#     654     x, y, style = parse_plot_args(*args, **options)
#     655     if isinstance(x, pd.DataFrame) or isinstance(y, pd.DataFrame):
# --> 656         raise ValueError("modsimpy.plot can't handle DataFrames.")
#     657
#     658     if x is None:
#
# ValueError: modsimpy.plot can't handle DataFrames.

# %%
wRange = linrange(100, 110, 1)

for w in wRange:
    sys = System(system, w=w)
    results, details = run_ode_solver(sys, slopeFunc, max_step = .1)
    plotPath(results, str(w) + ' rad/s')

# %%
results.X.plot()

# %%
results.Y.plot()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

v = 33
t = np.linspace(1,10,1)
theta = np.pi/9
h = 2

# Prepare arrays x, y, z
z = 1
x = v*t*np.cos(theta)
y = -16*t**2 + v*t*np.sin(theta) + h



ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()
